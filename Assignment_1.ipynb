# %%
1)

* This is the multiplication operator,which will be used for multiplication of two numbers.
Example 3*4



'hello' This is the string which will be assigned as a value to the variable.
Example a='hello,this is keerthi'




-87.8 This is the float decimal which will be assigned as a value to the variable.
Example num=-87.8




- This is the subtraction operator which will be used for subtracting two numbers.
Example 9-2




/ This is the divison operator which will be used for divison of two numbers.
Example 8/2



+ This is the addition operator which will be used for addition of two numbers.
Example 8+3



6 This is the integer number which will be assigned as a value to the variable.
Example number=6



2)
Variable: A variable is used for storing value.
Example:spam

string: A string is one of the kinds of value which can be stored in a variable.
Example:a='spam'

    
    
3)
Three different data forms:
Numbers,Sequence,boolean
1.Numbers-int,float,complex 
int-We refer this to integer numbers.
eg. 4
float-We can refer this as both integers and decimal numbers.
eg. 45.3
Complex-Combination of real and imaginary numbers.
eg 8+3j(where 8 is the real number and 3 is the imaginary number)

2.Sequence
String- A string is one of the kinds of value which can be stored in a variable.
Example:a='Hello World'

3.Boolean
True-it returns this when the condition is true
False-it returns this when the condition is false


4)
Expression: An expression is an representation of the value
Example:
1.37
2."How are you?"
3.4+4 
Functions of all expressions:They can be declared,assigned,copied or modified in the code.


5) 
spam=10 is a declaration since the value is assigned whereas only 'spam' is an expression.


6)
bacon=22
bacon+1
After running the code,bacon contains the value 23.


7)
'spam'+'spamspam' = 'spamspamspam'
'spam'*3= 'spamspamspam'


8)
eggs is a true variable name because it meets all the requirements that are required to be a variable.
100 is not a variable because variable does not start with digit.


9)
To convert a value to an integer,we should use int function
Example: a=94.2
         b=int(a)
         print(b)//prints 94


10)
'I have eaten'+99+'burritos.'
Type error
we should convert all the values to one common type
here,we can convert 99 to str
'I have eaten'+str(99)+'burritos.'
